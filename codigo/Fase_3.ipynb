# %%
from fase2_funciones import *
from Apriori import *
import os
import subprocess
from time import time

df_bd_preprocesada = pd.read_csv('BD/OnlineRetail_Preprocesada.csv', sep=',', encoding = 'unicode_escape')
df_pivot = df_bd_preprocesada['InvoiceDate'].str.split(expand = True)
df_pivot.rename(columns = {0: 'Fecha', 1: 'Hora'}, inplace=True)
df_bd_preprocesada = df_bd_preprocesada.drop(columns =['Unnamed: 0','InvoiceDate'])
df_bd_preprocesada = pd.concat([df_bd_preprocesada,df_pivot], axis = 1)
df_bd_preprocesada['Monto'] = df_bd_preprocesada['UnitPrice'] * df_bd_preprocesada['Quantity']

# %%
#--------------------Llamado a funciones ------------------
"""
articulos_libras_promedio (df_bd_preprocesada)
grupo_cliente(df_bd_preprocesada)5
numero_transacciones(df_bd_preprocesada)
"""
#---------------------Apriori general, soporte 0.01, confianza, confianza 0.1
#---------------------Se ejecuta el Apriori de 5*5 ccombinaciones
res = []
soporte = 0.01
confianza= 0.1
titulos = ["Posición", "Soporte", "Confianza", "Tiempo", "Reglas"]
res.append(titulos)
print("\n------------ Apriori general  ---------- \n")
for i in range (5):
    confianza = 0.1
    for j in range (5):
        start_time = time()
        apriori_general = a_priori(df_bd_preprocesada, soporte, confianza)
        elapsed_time = time() - start_time
        print("tiempo: %0.10f segundos. \n" % elapsed_time)
        print("número de reglas de asocación : {} \n".format(len(apriori_general)))
        detalle = [i, soporte, confianza, elapsed_time, len(apriori_general)]
        res.append(detalle)
        confianza = confianza + 0.1

    soporte = soporte + 0.004
        
print("número de reglas de asocación : {} \n".format(len(apriori_general)))
print (res)

#--------------------Se ejecuta el archivo Apriori.py-------------
# Out:
# ------------ Apriori general  ----------
#
# Soporte:   0.01
#
# Confianza:   0.1
#
# tiempo: 129.4467189312 segundos.
#
# Soporte:   0.01
#
# Confianza:   0.2
#
# tiempo: 132.3331193924 segundos.
#
# Soporte:   0.01
#
# Confianza:   0.30000000000000004
#
# tiempo: 130.9358689785 segundos.
#
# Soporte:   0.01
#
# Confianza:   0.4
#
# tiempo: 131.3072841167 segundos.
#
# Soporte:   0.01
#
# Confianza:   0.5
#
# tiempo: 131.7395913601 segundos.
#
# Soporte:   0.014
#
# Confianza:   0.1
#
# tiempo: 22.5038821697 segundos.
#
# Soporte:   0.014
#
# Confianza:   0.2
#
# tiempo: 22.5208091736 segundos.
#
# Soporte:   0.014
#
# Confianza:   0.30000000000000004
#
# tiempo: 22.2634694576 segundos.
#
# Soporte:   0.014
#
# Confianza:   0.4
#
# tiempo: 22.3921835423 segundos.
#
# Soporte:   0.014
#
# Confianza:   0.5
#
# tiempo: 22.1987652779 segundos.
#
# Soporte:   0.018000000000000002
#
# Confianza:   0.1
#
# tiempo: 7.0371673107 segundos.
#
# Soporte:   0.018000000000000002
#
# Confianza:   0.2
#
# tiempo: 7.0112612247 segundos.
#
# Soporte:   0.018000000000000002
#
# Confianza:   0.30000000000000004
#
# tiempo: 6.9484293461 segundos.
#
# Soporte:   0.018000000000000002
#
# Confianza:   0.4
#
# tiempo: 6.9665303230 segundos.
#
# Soporte:   0.018000000000000002
#
# Confianza:   0.5
#
# tiempo: 7.0032827854 segundos.
#
# Soporte:   0.022000000000000002
#
# Confianza:   0.1
#
# tiempo: 3.9085512161 segundos.
#
# Soporte:   0.022000000000000002
#
# Confianza:   0.2
#
# tiempo: 3.9664015770 segundos.
#
# Soporte:   0.022000000000000002
#
# Confianza:   0.30000000000000004
#
# tiempo: 3.9366838932 segundos.
#
# Soporte:   0.022000000000000002
#
# Confianza:   0.4
#
# tiempo: 3.9315199852 segundos.
#
# Soporte:   0.022000000000000002
#
# Confianza:   0.5
#
# tiempo: 3.9484484196 segundos.
#
# Soporte:   0.026000000000000002
#
# Confianza:   0.1
#
# tiempo: 3.0658059120 segundos.
#
# Soporte:   0.026000000000000002
#
# Confianza:   0.2
#
# tiempo: 3.1186652184 segundos.
#
# Soporte:   0.026000000000000002
#
# Confianza:   0.30000000000000004
#
# tiempo: 3.0548369884 segundos.
#
# Soporte:   0.026000000000000002
#
# Confianza:   0.4
#
# tiempo: 3.0658044815 segundos.
#
# Soporte:   0.026000000000000002
#
# Confianza:   0.5
#
# tiempo: 3.0887446404 segundos.
#
# número de reglas de asocación : 8
#
# [['Posición', 'Soporte', 'Confianza', 'Tiempo', 'Reglas'], [0, 0.01, 0.1, 129.44671893119812, 678], [0, 0.01, 0.2, 132.33311939239502, 678], [0, 0.01, 0.30000000000000004, 130.93586897850037, 630], [0, 0.01, 0.4, 131.307284116745, 494], [0, 0.01, 0.5, 131.73959136009216, 336], [1, 0.014, 0.1, 22.50388216972351, 226], [1, 0.014, 0.2, 22.520809173583984, 226], [1, 0.014, 0.30000000000000004, 22.263469457626343, 224], [1, 0.014, 0.4, 22.392183542251587, 182], [1, 0.014, 0.5, 22.19876527786255, 122], [2, 0.018000000000000002, 0.1, 7.037167310714722, 94], [2, 0.018000000000000002, 0.2, 7.011261224746704, 94], [2, 0.018000000000000002, 0.30000000000000004, 6.948429346084595, 94], [2, 0.018000000000000002, 0.4, 6.9665303230285645, 86], [2, 0.018000000000000002, 0.5, 7.003282785415649, 50], [3, 0.022000000000000002, 0.1, 3.9085512161254883, 50], [3, 0.022000000000000002, 0.2, 3.9664015769958496, 50], [3, 0.022000000000000002, 0.30000000000000004, 3.9366838932037354, 50], [3, 0.022000000000000002, 0.4, 3.9315199851989746, 48], [3, 0.022000000000000002, 0.5, 3.948448419570923, 32], [4, 0.026000000000000002, 0.1, 3.0658059120178223, 10], [4, 0.026000000000000002, 0.2, 3.1186652183532715, 10], [4, 0.026000000000000002, 0.30000000000000004, 3.0548369884490967, 10], [4, 0.026000000000000002, 0.4, 3.0658044815063477, 10], [4, 0.026000000000000002, 0.5, 3.088744640350342, 8]]

# %%
#Se importa pandas para la visualizacion de las combinaciones
#El tiempo visualizado está en segundos
import pandas as pd
rs = pd.DataFrame(res)
rs.head(40)
# Out:
#            0        1          2        3       4
# 0   Posición  Soporte  Confianza   Tiempo  Reglas
# 1          0     0.01        0.1  129.447     678
# 2          0     0.01        0.2  132.333     678
# 3          0     0.01        0.3  130.936     630
# 4          0     0.01        0.4  131.307     494
# 5          0     0.01        0.5   131.74     336
# 6          1    0.014        0.1  22.5039     226
# 7          1    0.014        0.2  22.5208     226
# 8          1    0.014        0.3  22.2635     224
# 9          1    0.014        0.4  22.3922     182
# 10         1    0.014        0.5  22.1988     122
# 11         2    0.018        0.1  7.03717      94
# 12         2    0.018        0.2  7.01126      94
# 13         2    0.018        0.3  6.94843      94
# 14         2    0.018        0.4  6.96653      86
# 15         2    0.018        0.5  7.00328      50
# 16         3    0.022        0.1  3.90855      50
# 17         3    0.022        0.2   3.9664      50
# 18         3    0.022        0.3  3.93668      50
# 19         3    0.022        0.4  3.93152      48
# 20         3    0.022        0.5  3.94845      32
# 21         4    0.026        0.1  3.06581      10
# 22         4    0.026        0.2  3.11867      10
# 23         4    0.026        0.3  3.05484      10
# 24         4    0.026        0.4   3.0658      10
# 25         4    0.026        0.5  3.08874       8

# %%
dfr = []
df_association_rules = []

#------------Enfoque particional, Soporte original 0.01,  confianza original 0.1 ----------
#------------se utilizarzán parcticiones de 2,4,6,8 y 10 ----------
print("\n------------ Enfoque particional  ---------- \n")

for i in range(10):
    print( " \nPartición  número : {} \n " .format(i+1))
    dfr.append(df_bd_preprocesada.sample(frac=0.1))
    start_time = time() #tiempo inicial
    df_association_rules.append(  a_priori(dfr[i], 0.001, 0.1))
    elapsed_time = time() - start_time #tiempo final
    print("tiempo: %0.10f segundos." % elapsed_time)
    print("número de reglas de asocación : {} " .format(len(df_association_rules[i])))
    print("\n----------------------------------------------- \n")
#Soporte, Confianza, respectivamente

#"------------ fin de apriori en particiones, se debe comparar con el general----------"
contador=0
for df in range(10):
    for i in apriori_general:
        for j in df_association_rules[df]:
            if i == j:
                contador  +=  1
    print("cantidad de coincidencias de partición {} con  apriori apriori general : {}" .format((df+1), contador))
    contador = 0
# Out:
# ------------ Enfoque particional  ----------
#
#
# Partición  número : 1
#
# Soporte:   0.001
#
# Confianza:   0.1
#
# tiempo: 243.2999918461 segundos.
# número de reglas de asocación : 36
#
# -----------------------------------------------
#
#
# Partición  número : 2
#
# Soporte:   0.001
#
# Confianza:   0.1
#
# tiempo: 239.9016296864 segundos.
# número de reglas de asocación : 20
#
# -----------------------------------------------
#
#
# Partición  número : 3
#
# Soporte:   0.001
#
# Confianza:   0.1
#
# tiempo: 239.3816807270 segundos.
# número de reglas de asocación : 20
#
# -----------------------------------------------
#
#
# Partición  número : 4
#
# Soporte:   0.001
#
# Confianza:   0.1
#
# tiempo: 234.1301748753 segundos.
# número de reglas de asocación : 32
#
# -----------------------------------------------
#
#
# Partición  número : 5
#
# Soporte:   0.001
#
# Confianza:   0.1
#
# tiempo: 240.7522997856 segundos.
# número de reglas de asocación : 34
#
# -----------------------------------------------
#
#
# Partición  número : 6
#
# Soporte:   0.001
#
# Confianza:   0.1
#
# tiempo: 234.0569486618 segundos.
# número de reglas de asocación : 12
#
# -----------------------------------------------
#
#
# Partición  número : 7
#
# Soporte:   0.001
#
# Confianza:   0.1
#
# tiempo: 246.0502643585 segundos.
# número de reglas de asocación : 28
#
# -----------------------------------------------
#
#
# Partición  número : 8
#
# Soporte:   0.001
#
# Confianza:   0.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-464f08d91a4b> in <module>
#      11     dfr.append(df_bd_preprocesada.sample(frac=0.1))
#      12     start_time = time() #tiempo inicial
# ---> 13     df_association_rules.append(  a_priori(dfr[i], 0.001, 0.1))
#      14     elapsed_time = time() - start_time #tiempo final
#      15     print("tiempo: %0.10f segundos." % elapsed_time)
#
# ~\Documents\Universidad\Ciencia de datos billy\Proyecto\github\codigo\Apriori.py in a_priori(df_bd_preprocesada, support, confidence)
#      34     association_rules = apriori(matriz, min_support=support, min_confidence=confidence, min_lift=3, min_length= None)
#      35     reglas = []
# ---> 36     for idx, x in enumerate(association_rules):
#      37         reglas.append(x.items)
#      38
#
# c:\users\felix\appdata\local\programs\python\python38-32\lib\site-packages\apyori.py in apriori(transactions, **kwargs)
#     284
#     285     # Calculate ordered stats.
# --> 286     for support_record in support_records:
#     287         ordered_statistics = list(
#     288             _filter_ordered_statistics(
#
# c:\users\felix\appdata\local\programs\python\python38-32\lib\site-packages\apyori.py in gen_support_records(transaction_manager, min_support, **kwargs)
#     197         if max_length and length > max_length:
#     198             break
# --> 199         candidates = _create_next_candidates(relations, length)
#     200
#     201
#
# c:\users\felix\appdata\local\programs\python\python38-32\lib\site-packages\apyori.py in create_next_candidates(prev_candidates, length)
#     155     # Filter candidates that all of their subsets are
#     156     # in the previous candidates.
# --> 157     next_candidates = [
#     158         candidate for candidate in tmp_next_candidates
#     159         if all(
#
# c:\users\felix\appdata\local\programs\python\python38-32\lib\site-packages\apyori.py in <listcomp>(.0)
#     157     next_candidates = [
#     158         candidate for candidate in tmp_next_candidates
# --> 159         if all(
#     160             frozenset(x) in prev_candidates
#     161             for x in combinations(candidate, length - 1))
#
# KeyboardInterrupt:
